# %%
__author__ = 'David Herrera <david.herrera@noirlab.edu>'# Based on notebook made by Alice Jacques <alice.jacques@noirlab.edu>, Robert Nikutta <robert.nikutta@noirlab.edu>'
__version__ = '20220627' # yyyymmdd; version datestamp of this notebook
__datasets__ = ['ls_dr10']  # datasets used in this notebook; for available datasets, see cell "Available datasets in Data Lab" further below
__keywords__ = ['qa','parallax','cmd']  # keywords relevant to this notebook, e.g. ['science case','dwarf galaxies'] Use only keywords from the master list: https://github.com/noaodatalab/notebooks_private/blob/master/internal/keywords.txt

# %% [markdown]
# # QA for LS DR10
# Legacy Survey Data Release 10

# %%
from time import time

import numpy as np
import pylab as plt
from matplotlib import cm
from matplotlib.ticker import MaxNLocator
# %matplotlib inline
import astropy.units as u
from astropy.coordinates import SkyCoord, CartesianRepresentation, SphericalRepresentation, matrix_utilities

from dl import queryClient as qc
from dl.helpers.utils import convert

# %%
qc.set_profile('db01')
qc.get_profile()
# Out:
# 'db01'

# %%
tables = ('ls_dr10.tractor_s_new',)
only_tables = ('tractor_s',)

# %% [markdown]
# # Presence of tables

# %%
for t in tables:
    print(t)
    print(qc.query("select * from %s limit 2" % t))
    print()
# Out:
# ls_dr10.tractor_s_new
# ...

# %% [markdown]
# # Compare columns in Table vs. columns in Tap Schema

# %%
for t in only_tables:
    print(f"Table: {t}")
    q_table = f"select column_name from information_schema.columns where table_schema=N'ls_dr10' and table_name=N'{t}'"
    re_table = qc.query(sql=q_table,fmt='pandas')
    print(f"Number of columns in Table: {len(re_table)}")
    q_tap = f"select column_name from tap_schema.columns where table_name like 'ls_dr10.{t}%'"
    re_tap = qc.query(sql=q_tap,fmt='pandas')
    print(f"Number of columns in Tap Schema: {len(re_tap)}")
    
    in_table_not_tap = list(set(re_table['column_name']) - set(re_tap['column_name']))
    in_tap_not_table = list(set(re_tap['column_name']) - set(re_table['column_name']))
    
    print(f"In Table not in Tap Schema: {in_table_not_tap}\n"
          f"In Tap Schema not in Table: {in_tap_not_table}\n")
# Out:
# Table: tractor_s
# Number of columns in Table: 0
# Number of columns in Tap Schema: 214
# In Table not in Tap Schema: []
# ...

# %% [markdown]
# # Row counts

# %%
for t in tables:
    start = time()
    print(t)
    print(qc.query("select count(*) from %s" % t))
    stop = time()
    print("Execution time: %g seconds\n\n" % (stop-start))
# Out:
# ls_dr10.tractor_s
# count
# 2837082990
#
# Execution time: 26.3145 seconds

# %% [markdown]
# # Distribution of values in columns (random sample)
# Plot simple quick histograms for a sample of all numerical columns in a given table. (Explicitly drop all non-numerical columns).

# %% [markdown]
# Functions for plotting figures and panels.

# %%
def make_panel(ax,data,bins=None,xlabel='',color='b',alpha=0.6):
    """Plot single panel to 'ax' object."""
    
    ax.hist(data,bins=bins,color=color,alpha=alpha)
    ax.set_xlabel(xlabel)
    ax.xaxis.set_major_locator(MaxNLocator(4))
    
def make_figure(df,nc=8,unitsize=4):
    """Plot quick histograms of all columns in df. Plot a numbe of single-row figures (for speed)."""
    
    cols = df.columns    
    nr = int(np.ceil(len(cols)/nc))  # compute number of rows needed
    
#    nr = 4  # for debuugging
    for jr in range(nr):
        fig, axes = plt.subplots(1,nc,figsize=(nc*unitsize,0.8*unitsize))
        axes = axes.flatten()
        mycols = cols[jr*nc:jr*nc+nc]
        nmycols = len(mycols)
        for j,c in enumerate(mycols):
            make_panel(axes[j],df[c],bins=30,xlabel=c)

        # set frame on any unsed panel to off
        if len(mycols) < nc:
            for ax in axes[-(nc-len(mycols)):]:
                ax.axis('off')

        print()
               
        plt.tight_layout()
        plt.show()
        plt.close()

# %%
# get a small random sample of all rows from given table
def run_query(table,random_id=(30,30.1)):
    df = qc.query("select * from %s where random_id between %f and %f" % (table,random_id[0],random_id[1]),fmt='pandas')
    df = df.select_dtypes(exclude=['object'])
    return df

# %%
# %%time
# loop over table, query, plot histograms of all columns
print("Querying table %s" % tables[0])
df = run_query(tables[0])
# Out:
# Querying table ls_dr10.tractor_s
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /data0/sw/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /data0/sw/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /data0/sw/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# ...

# %% [markdown]
# ##### The column `________` is dropped here because it is the same value for every row and produces an index error upon producing the plots below

# %%
df = df.drop(columns=['_________'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-960f53b95dc1> in <module>
# ----> 1 df = df.drop(columns=['_________'])
#
# /data0/sw/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /data0/sw/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# /data0/sw/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
print("shape:",df.shape)
print("Table %s" % tables[0])
make_figure(df,nc=6)
# Out:
# shape: (17299, 663)
# Table ls_dr10.tractor_load
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-728f2dedf4a3> in <module>
#       1 print("shape:",df.shape)
#       2 print("Table %s" % tables[0])
# ----> 3 make_figure(df,nc=6)
#
# <ipython-input-14-30c6a1b0c0e0> in make_figure(df, nc, unitsize)
#      19         nmycols = len(mycols)
#      20         for j,c in enumerate(mycols):
# ---> 21             make_panel(axes[j],df[c],bins=30,xlabel=c)
#      22
#      23         # set frame on any unsed panel to off
#
# <ipython-input-14-30c6a1b0c0e0> in make_panel(ax, data, bins, xlabel, color, alpha)
#       2     """Plot single panel to 'ax' object."""
#       3
# ----> 4     ax.hist(data,bins=bins,color=color,alpha=alpha)
#       5     ax.set_xlabel(xlabel)
#       6     ax.xaxis.set_major_locator(MaxNLocator(4))
#
# ...

# %%
# %%time
# loop over table, query, plot histograms of all columns
print("Querying table %s" % tables[1])
df1 = run_query(tables[1])
df1

# %%
df1 = df1.drop(columns=['solution_id'])

# %%
print("shape:",df1.shape)
print("Table %s" % tables[1])
make_figure(df1,nc=6)

# %%
# %%time
# loop over table, query, plot histograms of all columns
print("Querying table %s" % tables[2])
df2 = run_query(tables[2])
df2

# %%
df2 = df2.drop(columns=['solution_id'])

# %%
print("shape:",df2.shape)
print("Table %s" % tables[2])
make_figure(df2,nc=6)

# %%
# %%time
# loop over table, query, plot histograms of all columns
print("Querying table %s" % tables[3])
df3 = run_query(tables[3])
df3

# %%
df3 = df3.drop(columns=['solution_id'])

# %%
print("shape:",df3.shape)
print("Table %s" % tables[3])
make_figure(df3,nc=6)

# %% [markdown]
# # CMD
# Plot a sample CMD

# %%
# %%time
q = """select bp_g,bp_rp,g_rp,phot_g_mean_mag,phot_bp_mean_mag,phot_rp_mean_mag from gaia_dr3.gaia_source
        where phot_g_mean_mag != 'NaN'
        AND phot_bp_mean_mag != 'NaN'
        AND phot_rp_mean_mag != 'NaN'
        AND bp_g !='NaN'
        AND bp_rp !='NaN'
        AND g_rp !='NaN'
        limit 5000000"""
re = qc.query(sql=q,fmt='pandas',timeout=600)

# %%
plt.rcParams['font.size'] = 14
x1 = re['bp_g']
y1 = re['phot_bp_mean_mag']
fig, ax = plt.subplots(1,1,figsize=(8,8))
im = ax.hexbin(x1, y1, bins='log', cmap=plt.cm.viridis, mincnt=1)
ax.set_title('Color-Magnitude Diagram')
ax.set_xlabel('bp-g')
ax.set_ylabel('bp')
ax.set_ylim([max(y1) + 0.5, min(y1) - 0.5])
cb = plt.colorbar(im,ax=ax,label='log(N)')

# %%
plt.rcParams['font.size'] = 14
x1 = re['bp_rp']
y1 = re['phot_bp_mean_mag']
fig, ax = plt.subplots(1,1,figsize=(8,8))
im = ax.hexbin(x1, y1, bins='log', cmap=plt.cm.viridis, mincnt=1)
ax.set_title('Color-Magnitude Diagram')
ax.set_xlabel('bp-rp')
ax.set_ylabel('bp')
ax.set_ylim([max(y1) + 0.5, min(y1) - 0.5])
cb = plt.colorbar(im,ax=ax,label='log(N)')

# %%
plt.rcParams['font.size'] = 14
x1 = re['g_rp']
y1 = re['phot_g_mean_mag']
fig, ax = plt.subplots(1,1,figsize=(8,8))
im = ax.hexbin(x1, y1, bins='log', cmap=plt.cm.viridis, mincnt=1)
ax.set_title('Color-Magnitude Diagram')
ax.set_xlabel('g-rp')
ax.set_ylabel('g')
ax.set_ylim([max(y1) + 0.5, min(y1) - 0.5])
cb = plt.colorbar(im,ax=ax,label='log(N)')

# %% [markdown]
# # Proper motions with a quiver plot
# From Jupyter notebook science example [Visualizing Star Clusters in Gaia DR2](https://github.com/astro-datalab/notebooks-latest/blob/master/03_ScienceExamples/GalacticStructure/StarClustersGaiaDR2.ipynb)

# %%
# Write a query that returns all of the stars surrounding a particular object out to a particular radius 

def input_query(object_name, radius_deg):
    # SkyCoord.from_name outputs the coordinates of a particular object given its name as a string
    c = SkyCoord.from_name(object_name)
    
    # Construct a Cone Search query
    query = """SELECT * FROM gaia_dr3.gaia_source 
            WHERE (q3c_radial_query(ra, dec, {0}, {1}, %s)
            AND NOT parallax='NaN')""".format(c.ra.value,c.dec.value) % (radius_deg)
    
    # Submit the query
    response = qc.query(sql=query, fmt='csv')
    
    # Convert the query to a pandas DataFrame
    df = convert(response,'pandas')
    
    # Check the number of objects in your query
    print("The query of %s contains %s objects." % (object_name, len(df)))
    
    # Return the output DataFrame
    return df

# %%
# Pick your favorite object!

# Define an object
object_queried = "NGC 6281"

# Define a radius
radius = 0.5

# Submit the function that returns a queried DataFrame
df = input_query(object_queried, radius)

# %%
# Define variables from DataFrame
# Doing so within a function makes later re-definition very simple
def define_variables (df):
    ra, dec = df["ra"], df["dec"]
    ra_rad, dec_rad = np.radians(ra), np.radians(dec)
    pmra, pmdec = df["pmra"], df["pmdec"]
    parallax = df['parallax']
    g, g_bp = df["phot_g_mean_mag"], df["phot_g_mean_mag"]-df["phot_bp_mean_mag"]
    return ra, dec, ra_rad, dec_rad, pmra, pmdec, parallax, g, g_bp

# Submit the function that defines variables from the DataFrame
ra, dec, ra_rad, dec_rad, pmra, pmdec, parallax, g, g_bp = define_variables(df)

# %%
# Write a function that outputs spatial and color-color plots for your sampled object
def panel_plot(ra, dec, pmra, pmdec, color, mag):
    fig = plt.figure(figsize=(26,8))
    
    # A simple spatial plot
    ax1 = fig.add_subplot(131)
    ax1.scatter(ra, dec, marker='.', alpha= 1/np.power(len(df), 0.1))
    ax1.set_title("Spatial Plot",fontsize=10)
    ax1.set_xlabel("Right Ascension",fontsize=10)
    ax1.set_ylabel("Declination",fontsize=10)
    
    # A quiver plot (spatial plot with arrows that describe each object's proper motion)
    ax2 = fig.add_subplot(132)
    ax2.quiver(ra, dec, pmra, pmdec)
    ax2.set_title("Proper Motions",fontsize=10)
    ax2.set_xlabel("Right Ascension",fontsize=10)
    ax2.set_ylabel("Declination",fontsize=10)
    
    # A color-magnitude diagram that exhibits object density
    ax3 = fig.add_subplot(133)
    im3 = ax3.hexbin(g_bp, g, bins='log', cmap=plt.cm.viridis, mincnt=1)
    ax3.set_ylim(max(g), min(g))
    ax3.set_title("Color-Magnitude Diagram",fontsize=10)
    ax3.set_xlabel("Gaia G-BP Color",fontsize=10)
    ax3.set_ylabel("Gaia G Magnitude",fontsize=10)
    cb = plt.colorbar(im3,label='log(N)')

# %%
# Convert variables to SkyCoord object and impose limits on output

def convert_to_skycoord (g, ra_rad, dec_rad, parallax, dist1, dist2):
    # Define variables as as an numpy array and SkyCoord object
    # Note: The SkyCoord object contains data for ra, dec, and parallax
    mag = np.array(g)
    scnow = SkyCoord(np.array(ra_rad) * u.rad, np.array(dec_rad) * u.rad, 
                 distance=(np.array(parallax)*u.mas).to(u.pc, u.parallax()))

    # Create a "mask" with varying data thresholds (here depending on magnitude and distance)
    msk = (mag < 16)  & (scnow.distance > dist1*u.pc) & (scnow.distance < dist2*u.pc)
    
    # Apply data thresholds to the given magnitude and SkyCoord objects
    mag = mag[msk]
    scnow = scnow[msk]
    
    # Print the new object count after applying data thresholds
    print('After the thresholds are applied, this query contains %s objects.' % (len(scnow)))
    
    # Return the defined variables
    return mag, msk, scnow
    
mag, msk, scnow = convert_to_skycoord(g, ra_rad, dec_rad, parallax, 1e2, 9e2)

# %%
# Call stationary plot
panel_plot(scnow.ra, scnow.dec, pmra[msk], pmdec[msk], g_bp[msk], g[msk])
